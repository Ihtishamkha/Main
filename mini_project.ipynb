# %%
pip install rdkit
# Out:
# Collecting rdkit
#   Downloading rdkit-2025.9.4-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from rdkit) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit) (11.3.0)
# Downloading rdkit-2025.9.4-cp312-cp312-manylinux_2_28_x86_64.whl (36.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.6/36.6 MB 29.2 MB/s eta 0:00:00
# Installing collected packages: rdkit
# Successfully installed rdkit-2025.9.4

# %%
import pandas as pd
df=pd.read_csv("/content/Aromatase.csv", sep=";")
df
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 0           CHEMBL66775           NaN                 NaN            318.48
# 1          CHEMBL176098           NaN                 NaN            251.33
# 2          CHEMBL176886           NaN                 NaN            251.33
# 3          CHEMBL175962           NaN                 NaN            207.28
# 4          CHEMBL366773           NaN                 NaN            286.17
# ...                 ...           ...                 ...               ...
# 7017      CHEMBL5887888           NaN                 NaN            408.85
# 7018      CHEMBL5808901           NaN                 NaN            374.40
# 7019      CHEMBL5873947           NaN                 NaN            442.30
# 7020      CHEMBL5808901           NaN                 NaN            374.40
# 7021      CHEMBL5916153           NaN                 NaN            389.41
#
#       #RO5 Violations  AlogP Compound Key  \
# 0                 0.0   4.00            4
# 1                 0.0   3.97           14
# 2                 0.0   3.97           17
# 3                 0.0   3.57           26
# 4                 0.0   4.33           33
# ...               ...    ...          ...
# 7017              0.0   3.93   BDBM582699
# 7018              0.0   3.28   BDBM582683
# 7019              1.0   5.19   BDBM582675
# 7020              0.0   3.28   BDBM582683
# 7021              0.0   3.59   BDBM582686
#
#                                                  Smiles      Standard Type  \
# 0     C[C@]12C[C@@H](S)C(=O)C=C1CCC1C2CC[C@]2(C)C(=O...  Activity remaning
# 1                        COc1ccc2c(c1)CCC/C2=C/c1cccnc1               IC50
# 2                        CCOc1ccc2c(c1)CC/C2=C/c1cccnc1               IC50
# 3                           C(=C1\CCc2ccccc21)\c1ccncc1               IC50
# 4                         Brc1ccc2c(c1)CC/C2=C\c1ccncc1               IC50
# ...                                                 ...                ...
# 7017   O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)c(Cl)cc2N1                kon
# 7018       O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)ccc2N1                kon
# 7019  O=C1COc2cc(NCc3cccc(NC(=O)c4ccccc4Cl)c3)c(Cl)c...                kon
# 7020       O=C1COc2cc(NCc3cccc(C(=O)Nc4cccnc4)c3)ccc2N1              k_off
# 7021      O=C1COc2cc(NCc3cccc(C(=O)Nc4ccccc4O)c3)ccc2N1              k_off
#
#      Standard Relation  ...  Document ChEMBL ID Source ID  \
# 0                  '='  ...       CHEMBL1124325         1
# 1                  '='  ...       CHEMBL1240479         1
# 2                  '='  ...       CHEMBL1240479         1
# 3                  '='  ...       CHEMBL1240479         1
# 4                  '='  ...       CHEMBL1240479         1
# ...                ...  ...                 ...       ...
# 7017               '='  ...       CHEMBL5729535        37
# 7018               '='  ...       CHEMBL5729535        37
# 7019               '='  ...       CHEMBL5729535        37
# 7020               '='  ...       CHEMBL5729535        37
# 7021               '='  ...       CHEMBL5729535        37
#
#                      Source Description Document Journal Document Year  \
# 0                 Scientific Literature       J Med Chem          1989
# 1                 Scientific Literature   Eur J Med Chem          2010
# 2                 Scientific Literature   Eur J Med Chem          2010
# 3                 Scientific Literature   Eur J Med Chem          2010
# 4                 Scientific Literature   Eur J Med Chem          2010
# ...                                 ...              ...           ...
# 7017  BindingDB Patent Bioactivity Data              NaN          2023
# 7018  BindingDB Patent Bioactivity Data              NaN          2023
# 7019  BindingDB Patent Bioactivity Data              NaN          2023
# 7020  BindingDB Patent Bioactivity Data              NaN          2023
# 7021  BindingDB Patent Bioactivity Data              NaN          2023
#
#      Cell ChEMBL ID  Properties  Action Type  Standard Text Value   Value
# 0               NaN         NaN          NaN                  NaN  75.000
# 1               NaN         NaN          NaN                  NaN   4.000
# 2               NaN         NaN          NaN                  NaN   7.680
# 3               NaN         NaN          NaN                  NaN   6.700
# 4               NaN         NaN          NaN                  NaN   2.469
# ...             ...         ...          ...                  ...     ...
# 7017            NaN         NaN          NaN                  NaN     NaN
# 7018            NaN         NaN          NaN                  NaN     NaN
# 7019            NaN         NaN          NaN                  NaN     NaN
# 7020            NaN         NaN          NaN                  NaN     NaN
# 7021            NaN         NaN          NaN                  NaN     NaN
#
# [7022 rows x 48 columns]

# %%
df.columns
# Out:
# Index(['Molecule ChEMBL ID', 'Molecule Name', 'Molecule Max Phase',
#        'Molecular Weight', '#RO5 Violations', 'AlogP', 'Compound Key',
#        'Smiles', 'Standard Type', 'Standard Relation', 'Standard Value',
#        'Standard Units', 'pChEMBL Value', 'Data Validity Comment', 'Comment',
#        'Uo Units', 'Ligand Efficiency BEI', 'Ligand Efficiency LE',
#        'Ligand Efficiency LLE', 'Ligand Efficiency SEI', 'Potential Duplicate',
#        'Assay ChEMBL ID', 'Assay Description', 'Assay Type', 'BAO Format ID',
#        'BAO Label', 'Assay Organism', 'Assay Tissue ChEMBL ID',
#        'Assay Tissue Name', 'Assay Cell Type', 'Assay Subcellular Fraction',
#        'Assay Parameters', 'Assay Variant Accession', 'Assay Variant Mutation',
#        'Target ChEMBL ID', 'Target Name', 'Target Organism', 'Target Type',
#        'Document ChEMBL ID', 'Source ID', 'Source Description',
#        'Document Journal', 'Document Year', 'Cell ChEMBL ID', 'Properties',
#        'Action Type', 'Standard Text Value', 'Value'],
#       dtype='object')

# %%
df_pchembl=df[df['pChEMBL Value'].notnull()]
df_pchembl
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 1          CHEMBL176098           NaN                 NaN            251.33
# 2          CHEMBL176886           NaN                 NaN            251.33
# 3          CHEMBL175962           NaN                 NaN            207.28
# 7          CHEMBL223874           NaN                 NaN            308.38
# 8          CHEMBL387892           NaN                 NaN            256.26
# ...                 ...           ...                 ...               ...
# 7012      CHEMBL5406393           NaN                 NaN            384.42
# 7013      CHEMBL5423824           NaN                 NaN            477.34
# 7014      CHEMBL5402457           NaN                 NaN            398.26
# 7015      CHEMBL5440356           NaN                 NaN            321.34
# 7016         CHEMBL1444     LETROZOLE                 4.0            285.31
#
#       #RO5 Violations  AlogP Compound Key  \
# 1                 0.0   3.97           14
# 2                 0.0   3.97           17
# 3                 0.0   3.57           26
# 7                 0.0   4.70           14
# 8                 0.0   2.05           18
# ...               ...    ...          ...
# 7012              0.0   1.24         1085
# 7013              0.0   2.40         1092
# 7014              0.0   3.52         1100
# 7015              0.0   2.20         1101
# 7016              0.0   2.66          LTZ
#
#                                                  Smiles Standard Type  \
# 1                        COc1ccc2c(c1)CCC/C2=C/c1cccnc1          IC50
# 2                        CCOc1ccc2c(c1)CC/C2=C/c1cccnc1          IC50
# 3                           C(=C1\CCc2ccccc21)\c1ccncc1          IC50
# 7               c1ccc(C2(n3ccnc3)c3ccccc3-c3ccccc32)cc1          IC50
# 8                        COc1ccc2cc(Cn3ccnc3)c(=O)oc2c1          IC50
# ...                                                 ...           ...
# 7012     N#Cc1ccc(N(CCc2ccc(OS(N)(=O)=O)cc2)n2cnnc2)cc1          IC50
# 7013  N#Cc1ccc(N(CCCc2ccc(OS(N)(=O)=O)c(Br)c2)n2cnnc...          IC50
# 7014          N#Cc1ccc(N(CCCc2ccc(O)c(Br)c2)n2cnnc2)cc1          IC50
# 7015              N#Cc1ccc(N(CCOc2ccc(O)cc2)n2cnnc2)cc1          IC50
# 7016               N#Cc1ccc(C(c2ccc(C#N)cc2)n2cncn2)cc1          IC50
#
#      Standard Relation  ...  Document ChEMBL ID Source ID  \
# 1                  '='  ...       CHEMBL1240479         1
# 2                  '='  ...       CHEMBL1240479         1
# 3                  '='  ...       CHEMBL1240479         1
# 7                  '='  ...       CHEMBL1149306         1
# 8                  '='  ...       CHEMBL1149306         1
# ...                ...  ...                 ...       ...
# 7012               '='  ...       CHEMBL5375941         1
# 7013               '='  ...       CHEMBL5375941         1
# 7014               '='  ...       CHEMBL5375941         1
# 7015               '='  ...       CHEMBL5375941         1
# 7016               '='  ...       CHEMBL5512683         1
#
#          Source Description Document Journal Document Year Cell ChEMBL ID  \
# 1     Scientific Literature   Eur J Med Chem          2010            NaN
# 2     Scientific Literature   Eur J Med Chem          2010            NaN
# 3     Scientific Literature   Eur J Med Chem          2010            NaN
# 7     Scientific Literature       J Med Chem          2004            NaN
# 8     Scientific Literature       J Med Chem          2004            NaN
# ...                     ...              ...           ...            ...
# 7012  Scientific Literature   Eur J Med Chem          2017            NaN
# 7013  Scientific Literature   Eur J Med Chem          2017            NaN
# 7014  Scientific Literature   Eur J Med Chem          2017            NaN
# 7015  Scientific Literature   Eur J Med Chem          2017            NaN
# 7016  Scientific Literature       J Med Chem          2024            NaN
#
#            Properties  Action Type  Standard Text Value   Value
# 1                 NaN          NaN                  NaN  4.0000
# 2                 NaN          NaN                  NaN  7.6800
# 3                 NaN          NaN                  NaN  6.7000
# 7                 NaN          NaN                  NaN -7.1300
# 8                 NaN          NaN                  NaN -5.5500
# ...               ...          ...                  ...     ...
# 7012  TIME = 16.08 hr    INHIBITOR                  NaN  8.6780
# 7013  TIME = 16.08 hr    INHIBITOR                  NaN  8.8240
# 7014  TIME = 16.08 hr    INHIBITOR                  NaN  9.4440
# 7015  TIME = 16.08 hr    INHIBITOR                  NaN  7.5850
# 7016              NaN     DEGRADER                  NaN  0.0018
#
# [4462 rows x 48 columns]

# %%
df_pchembl["pChEMBL Value"]
# Out:
# 1       5.40
# 2       5.12
# 3       5.17
# 7       7.13
# 8       5.55
#         ...
# 7012    8.68
# 7013    8.82
# 7014    9.44
# 7015    7.58
# 7016    8.74
# Name: pChEMBL Value, Length: 4462, dtype: float64

# %%
df_pchembl['Potential Duplicate'].value_counts()
# Out:
# Potential Duplicate
# 0    3724
# 1     738
# Name: count, dtype: int64

# %%
df_pchembl[df_pchembl["Potential Duplicate"]==0]
# Out:
#      Molecule ChEMBL ID Molecule Name  Molecule Max Phase  Molecular Weight  \
# 7          CHEMBL223874           NaN                 NaN            308.38
# 8          CHEMBL387892           NaN                 NaN            256.26
# 9          CHEMBL224787           NaN                 NaN            332.36
# 11         CHEMBL255108           NaN                 NaN            299.33
# 12          CHEMBL26065           NaN                 NaN            237.26
# ...                 ...           ...                 ...               ...
# 7011      CHEMBL5398859           NaN                 NaN            386.31
# 7012      CHEMBL5406393           NaN                 NaN            384.42
# 7013      CHEMBL5423824           NaN                 NaN            477.34
# 7014      CHEMBL5402457           NaN                 NaN            398.26
# 7015      CHEMBL5440356           NaN                 NaN            321.34
#
#       #RO5 Violations  AlogP   Compound Key  \
# 7                 0.0   4.70             14
# 8                 0.0   2.05             18
# 9                 0.0   3.71             32
# 11                0.0   4.42  Table 3, R3C3
# 12                0.0   2.61            T70
# ...               ...    ...            ...
# 7011              1.0   5.49           1044
# 7012              0.0   1.24           1085
# 7013              0.0   2.40           1092
# 7014              0.0   3.52           1100
# 7015              0.0   2.20           1101
#
#                                                  Smiles Standard Type  \
# 7               c1ccc(C2(n3ccnc3)c3ccccc3-c3ccccc32)cc1          IC50
# 8                        COc1ccc2cc(Cn3ccnc3)c(=O)oc2c1          IC50
# 9             COc1ccc2c(-c3ccccc3)c(Cn3ccnc3)c(=O)oc2c1          IC50
# 11                N#Cc1ccc(C2CC(=O)c3ccc4ccccc4c3O2)cc1          IC50
# 12                     O=C1/C(=C/c2ccncc2)Cc2cc(O)ccc21          IC50
# ...                                                 ...           ...
# 7011        Clc1ccc(C(c2ccc(Cl)cc2)(c2ccsn2)n2ccnc2)cc1          IC50
# 7012     N#Cc1ccc(N(CCc2ccc(OS(N)(=O)=O)cc2)n2cnnc2)cc1          IC50
# 7013  N#Cc1ccc(N(CCCc2ccc(OS(N)(=O)=O)c(Br)c2)n2cnnc...          IC50
# 7014          N#Cc1ccc(N(CCCc2ccc(O)c(Br)c2)n2cnnc2)cc1          IC50
# 7015              N#Cc1ccc(N(CCOc2ccc(O)cc2)n2cnnc2)cc1          IC50
#
#      Standard Relation  ...  Document ChEMBL ID Source ID  \
# 7                  '='  ...       CHEMBL1149306         1
# 8                  '='  ...       CHEMBL1149306         1
# 9                  '='  ...       CHEMBL1149306         1
# 11                 '='  ...       CHEMBL1143207         1
# 12                 '='  ...       CHEMBL1139479         1
# ...                ...  ...                 ...       ...
# 7011               '='  ...       CHEMBL5375941         1
# 7012               '='  ...       CHEMBL5375941         1
# 7013               '='  ...       CHEMBL5375941         1
# 7014               '='  ...       CHEMBL5375941         1
# 7015               '='  ...       CHEMBL5375941         1
#
#          Source Description Document Journal Document Year Cell ChEMBL ID  \
# 7     Scientific Literature       J Med Chem          2004            NaN
# 8     Scientific Literature       J Med Chem          2004            NaN
# 9     Scientific Literature       J Med Chem          2004            NaN
# 11    Scientific Literature  Bioorg Med Chem          2008            NaN
# 12    Scientific Literature       J Med Chem          2005            NaN
# ...                     ...              ...           ...            ...
# 7011  Scientific Literature   Eur J Med Chem          2017            NaN
# 7012  Scientific Literature   Eur J Med Chem          2017            NaN
# 7013  Scientific Literature   Eur J Med Chem          2017            NaN
# 7014  Scientific Literature   Eur J Med Chem          2017            NaN
# 7015  Scientific Literature   Eur J Med Chem          2017            NaN
#
#            Properties  Action Type  Standard Text Value  Value
# 7                 NaN          NaN                  NaN -7.130
# 8                 NaN          NaN                  NaN -5.550
# 9                 NaN          NaN                  NaN -6.970
# 11                NaN          NaN                  NaN  1.540
# 12                NaN          NaN                  NaN  4.660
# ...               ...          ...                  ...    ...
# 7011  TIME = 16.08 hr    INHIBITOR                  NaN  7.244
# 7012  TIME = 16.08 hr    INHIBITOR                  NaN  8.678
# 7013  TIME = 16.08 hr    INHIBITOR                  NaN  8.824
# 7014  TIME = 16.08 hr    INHIBITOR                  NaN  9.444
# 7015  TIME = 16.08 hr    INHIBITOR                  NaN  7.585
#
# [3724 rows x 48 columns]

# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import AllChem
from rdkit.Chem import PandasTools

def identify_duplicates(df, smiles_column):
    """Identifies duplicate molecules in a dataset using SMILES strings."""
    def standardize_smiles(smiles):
        """Standardize SMILES to canonical form"""
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return None
            return Chem.MolToSmiles(mol, canonical=True)
        except:
            return None

    def calculate_inchi_key(smiles):
        """Calculate InChI Key for a SMILES string"""
        try:
            mol = Chem.MolFromSmiles(smiles)
            if mol is None:
                return None
            return Chem.MolToInchiKey(mol)
        except:
            return None

    # Create a copy of the dataframe
    df_analysis = df.copy()

    # Add standardized SMILES
    df_analysis['canonical_smiles'] = df_analysis[smiles_column].apply(standardize_smiles)

    # Add InChI Keys
    df_analysis['inchi_key'] = df_analysis['canonical_smiles'].apply(calculate_inchi_key)

    # Mark invalid SMILES
    df_analysis['is_valid'] = df_analysis['canonical_smiles'].notna()

    # Identify duplicates
    df_analysis['is_duplicate'] = df_analysis['inchi_key'].duplicated(keep='first')

    # Group duplicates
    df_analysis['duplicate_group'] = df_analysis.groupby('inchi_key').ngroup()

    # Count occurrences of each molecule
    duplicate_counts = df_analysis['inchi_key'].value_counts()
    df_analysis['occurrence_count'] = df_analysis['inchi_key'].map(duplicate_counts)

    return df_analysis

def get_duplicate_summary(df_analysis):
    """Generates a summary of duplicate analysis"""
    summary = {
        'total_molecules': len(df_analysis),
        'invalid_smiles': (~df_analysis['is_valid']).sum(),
        'unique_molecules': df_analysis['inchi_key'].nunique(),
        'duplicate_molecules': df_analysis['is_duplicate'].sum(),
        'molecules_with_duplicates': len(df_analysis[df_analysis['occurrence_count'] > 1]),
        'max_duplicates': df_analysis['occurrence_count'].max()
    }
    return summary

# %%
df_analyzed = identify_duplicates(df_pchembl, 'Smiles')
print(df_analyzed)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-22271825.py in <cell line: 0>()
# ----> 1 df_analyzed = identify_duplicates(df_pchembl, 'Smiles')
#       2 print(df_analyzed)
#
# NameError: name 'identify_duplicates' is not defined

# %%
# Get summary of duplicate molecules
summary = get_duplicate_summary(df_analyzed)
summary
# Out:
# {'total_molecules': 4462,
#  'invalid_smiles': np.int64(0),
#  'unique_molecules': 2985,
#  'duplicate_molecules': np.int64(1477),
#  'molecules_with_duplicates': 2328,
#  'max_duplicates': 50}

# %%
import pandas as pd
import numpy as np

def process_duplicates(df, inchi_key_col, pchembl_col):
    """Process duplicates with different handling for zero-SD and non-zero-SD groups."""
    # Create working copy
    df_work = df.copy()

    # Calculate group statistics
    group_stats = df_work.groupby(inchi_key_col).agg({
        pchembl_col: ['count', 'mean', 'std']
    }).round(4)

    group_stats.columns = ['count', 'mean', 'std']
    group_stats = group_stats.reset_index()

    # Filter for groups with multiple entries
    duplicate_groups = group_stats[group_stats['count'] > 1].copy()
    # Identify single entry compounds
    single_entry_groups = group_stats[group_stats['count'] == 1].copy()

    # Initialize list for processed rows and duplicates info
    processed_rows = []
    compounds_with_dups = []

    # Process each group
    for inchi_key in group_stats['inchi_key']:
        group_data = df_work[df_work[inchi_key_col] == inchi_key].copy()
        group_stats_row = group_stats[group_stats['inchi_key'] == inchi_key].iloc[0]

        if len(group_data) > 1:  # Multiple entries
            # Add statistics to group data
            group_data['group_mean'] = group_stats_row['mean']
            group_data['group_std'] = group_stats_row['std']
            compounds_with_dups.append(group_data)

            if group_stats_row['std'] == 0:  # Zero-SD group
                # Keep only the first row for zero-SD groups
                processed_row = group_data.iloc[[0]].copy()
                processed_row['group_type'] = 'zero_sd'
            else:  # Non-zero-SD group
                # Keep first row but update pChEMBL value with mean
                processed_row = group_data.iloc[[0]].copy()
                processed_row[pchembl_col] = group_stats_row['mean']
                processed_row['group_type'] = 'nonzero_sd'

            processed_rows.append(processed_row)

        else:  # Single entry
            group_data['group_type'] = 'single_entry'
            processed_rows.append(group_data)

    # Combine all processed rows
    final_df = pd.concat(processed_rows)
    compounds_with_duplicates_df = pd.concat(compounds_with_dups) if compounds_with_dups else pd.DataFrame()

    # Create summary
    summary_stats = {
        'total_initial_compounds': len(df),
        'total_unique_inchikeys': len(group_stats),
        'single_entry_compounds': len(single_entry_groups),
        'compounds_with_duplicates': len(duplicate_groups),
        'zero_sd_groups': len(duplicate_groups[duplicate_groups['std'] == 0]),
        'nonzero_sd_groups': len(duplicate_groups[duplicate_groups['std'] > 0]),
        'final_compounds': len(final_df)
    }

    summary_df = pd.DataFrame([summary_stats]).transpose()
    summary_df.columns = ['count']

    # Sort final DataFrame by InChI key
    final_df = final_df.sort_values(by=[inchi_key_col])

    return final_df, summary_df, compounds_with_duplicates_df

# Here, we'll call the process_duplicates() function on the DataFrame df_analyzed to process duplicate molecules.

# Briefly, we'll use the 'inchi_key' and 'pChEMBL Value' as the input, and finally unpacking the 3 returned DataFrames into separate variables.


final_df, summary_df, compounds_with_dups_df = process_duplicates(
    df_analyzed,
    inchi_key_col='inchi_key',
    pchembl_col='pChEMBL Value'
)

# %%
final_df.group_type.value_counts()
# Out:
# group_type
# single_entry    2134
# nonzero_sd       462
# zero_sd          389
# Name: count, dtype: int64

# %%
# Create a DataFrame subset
nonredundant_df = final_df[['Molecule ChEMBL ID', 'canonical_smiles', 'inchi_key', 'pChEMBL Value', 'Document ChEMBL ID']]

# Replace spaces with underscores and convert to lowercase in column names
nonredundant_df.columns = nonredundant_df.columns.str.replace(' ', '_').str.lower()

nonredundant_df
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 4264       CHEMBL313774                  O=C1/C(=C/c2ccncc2)CCc2ccc(O)cc21
# 3794      CHEMBL4087613                CCN(CC)c1ccc2cc(-c3cnco3)c(=O)oc2c1
# 3391      CHEMBL5432300            COc1ccc(/C=C/c2ccccc2[N+](=O)[O-])cc1OC
# 3618      CHEMBL3753297  CC(=O)O[C@]12CCCCC1=CC(=O)[C@H]1[C@@H]3CCC(=O)...
# 1018      CHEMBL4536893        O=[N+]([O-])c1ccc(N(Cc2ccccc2)n2cnnc2)cc1Br
# ...                 ...                                                ...
# 1836      CHEMBL2312958       O=C1CCc2cc(C(c3ccncc3)c3cccc(F)c3)cc3c2N1CC3
# 3722      CHEMBL3622077  CC(C)(C#N)c1cc(/C=C/c2ccc(OS(N)(=O)=O)cc2)cc(C...
# 1566      CHEMBL5416513     N#Cc1ccc(C(CCc2ccc(OS(N)(=O)=O)cc2)n2cncn2)cc1
# 2665       CHEMBL288804         CCN1CCc2cc(Cl)cc(C(c3ccc(F)cc3)n3ccnc3)c21
# 698       CHEMBL3753463  C[C@]12C=CC(=O)C=C1[C@@H](CC=O)C[C@@H]1[C@@H]2...
#
#                         inchi_key  pchembl_value document_chembl_id
# 4264  AAARKAYZOWLPBX-UKTHLTGXSA-N           5.52      CHEMBL5375941
# 3794  AAERCJJMMQESJP-UHFFFAOYSA-N           5.51      CHEMBL4020780
# 3391  AAICSQDTJISOED-VQHVLOKHSA-N           5.50      CHEMBL5375941
# 3618  AANWPSJJHRRISJ-HVXNZKGKSA-N           5.96      CHEMBL3751755
# 1018  ABCAGXYFNPKNRK-UHFFFAOYSA-N           7.40      CHEMBL4477276
# ...                           ...            ...                ...
# 1836  ZZBHFQHOABMONM-UHFFFAOYSA-N           7.13      CHEMBL2311453
# 3722  ZZDNFXFMCLATNS-ONEGZZNKSA-N           7.59      CHEMBL3621110
# 1566  ZZGLNABOHZSJOP-UHFFFAOYSA-N           9.66      CHEMBL5375941
# 2665  ZZVWJQNVTDFWKN-UHFFFAOYSA-N           7.20      CHEMBL1136431
# 698   ZZWIVTZHEAIWFH-QAXSQSOOSA-N           5.60      CHEMBL3751755
#
# [2985 rows x 5 columns]

# %%
nonredundant_df.to_csv('CHEMBL1978_nonredundant.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3364648455.py in <cell line: 0>()
# ----> 1 nonredundant_df.to_csv('CHEMBL1978_nonredundant.csv', index=False)
#
# NameError: name 'nonredundant_df' is not defined
